# %% [markdown]
# # Build ANN model with airline passengers data
#
# **We already know that the airline passengers data shows a linear trend as well as seasonality, so it is an excellent dataset to demonstrate the power of a regression neural network, compared to the more standardized models.**
#
# **Using TensorFlow, build an ANN model that forecasts the univariate time series, i.e. specified number of timesteps in the future, after the end of the training set. Since Keras API in TensorFlow behaves similar to SciKit-Learn, you need to create a 'supervised' dataset, i.e. input *X* and target *Y* variables. This is a regression model so you can use three types of forecasting - one-step, incremental multi-step, which incrementally returns multiple timesteps into the future, and multi-output multi-step, which outputs multiple timesteps into the future in one go.**
#
# **NOTE: You must ensure stationarity in data to train the model, by log-transformation and differencing. This means you need to undo the differencing before forecasting in order to return predictions on the same scale as original data. There are some neural networks that are powerful enough that differencing is not necessary, but that can only be known by testing.**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# To return consistent results - in the real world, turn this off
np.random.seed(123)

# %matplotlib inline

# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.models import Model

# To return consistent results
tf.random.set_seed(123)

# %%
from sklearn.metrics import mean_absolute_percentage_error

# %%
# Index frequency is start of the month

df = pd.read_csv('data/airline_passengers.csv', index_col='Month', parse_dates=True)

# %%
df['LogPassengers'] = np.log(df['Passengers'])

# %%
df['DiffLogPassengers'] = df['LogPassengers'].diff()

# %%
# Plot most recent months

df['DiffLogPassengers'][-40:].plot(figsize=(15, 5));

# %%
# Note null value due to differencing

df.head()
# Out:
#             Passengers  LogPassengers  DiffLogPassengers
# Month
# 1949-01-01         112       4.718499                NaN
# 1949-02-01         118       4.770685           0.052186
# 1949-03-01         132       4.882802           0.112117
# 1949-04-01         129       4.859812          -0.022990
# 1949-05-01         121       4.795791          -0.064022

# %%
# Create training and test sets

N_test = 12

train = df.iloc[:-N_test]
test = df.iloc[-N_test:]

# %%
# Boolean series to index df rows

train_idx = df.index <= train.index[-1]
test_idx = df.index > train.index[-1]

# %% [markdown]
# ## Make 'supervised' dataset
#
# **Create input *X* and target *Y* variables using AutoRegressive method with *T* past values to predict the next value. From there, you can split *X* and *Y* into training and test sets used for supervised machine-learning.**
#
# **The T number of past lags defines how many columns in the *X* variable for input to predicting the next value. It is also the input shape specification for the ANN model. The target variable contains a single value for each timestep, which is the predicted next value after AutoRegression.**
#
# **NOTE: Remember that the time series has been differenced to ensure stationarity. The ANN is trained on the differenced data, but you will need to undo the differencing before generating predictions on the same scale as the original data.**

# %%
series = df['DiffLogPassengers'].dropna().to_numpy()

# 10 past lags
T = 10
X = []
Y = []

for t in range(len(series) - T):
    x = series[t:t+T]
    X.append(x)
    y = series[t+T]
    Y.append(y)

# Convert to NumPy arrays
X = np.array(X).reshape(-1, T)
Y = np.array(Y)

N = len(X)

print("X.shape", X.shape, "Y.shape", Y.shape)
# Out:
# X.shape (133, 10) Y.shape (133,)

# %%
# Split X and Y into X_train, y_train, X_test, y_test

X_train, y_train = X[:-N_test], Y[:-N_test]

X_test, y_test = X[-N_test:], Y[-N_test:]

# %% [markdown]
# ## Build basic ANN
#
# **The basic ANN is a feed-forward network that works for tabular data and univariate time series.**
#
# **To create the model:**
#
# * **The inner layer, or `Input`, specifies the dimension of your input, *T* x *N*, where *T* is the number of features. In a time series, each feature is the current or past timestep values.**
#
# * **The hidden layer(s), or `Dense` layer, specifies the number of hidden nodes and activation function to be used. You can chain in more dense layers to make a deeper neural network in order to improve model performance, but this is a matter of trial-and-error. For regression tasks, the standard starting point is 32 nodes and ReLU activation function.**
#
# * **The outer layer, or the final `Dense` layer, specifies the number of outputs, *K*. For example, for one-step forecast `K=1`, and for ten multi-output forecast `K=10` etc.**
#
# **The model is instantiated by passing in the input and chain of subsequent layers.**
#
# **NOTE: Remember to flatten predictions to 1D NumPy array before adding to them original data and plotting.**

# %%
i = Input(shape=(T,))

x = Dense(32, activation='relu')(i)

x = Dense(1)(x)

model = Model(i, x)

# %%
# Tell model what to optimize - can add additional metrics, like MAE

model.compile(loss='mse', optimizer='adam')

# %%
# Train the model - epochs is number of loops over the training data

r = model.fit(X_train, 
              y_train, 
              epochs=150, 
              validation_data=(X_test, y_test))
# Out:
# Epoch 1/150
# 4/4 [==============================] - 1s 78ms/step - loss: 0.0148 - val_loss: 0.0126
# Epoch 2/150
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0128 - val_loss: 0.0111
# Epoch 3/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0115 - val_loss: 0.0101
# Epoch 4/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0106 - val_loss: 0.0092
# Epoch 5/150
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0095 - val_loss: 0.0082
# Epoch 6/150
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0088 - val_loss: 0.0073
# Epoch 7/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0080 - val_loss: 0.0066
# Epoch 8/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0073 - val_loss: 0.0059
# Epoch 9/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0067 - val_loss: 0.0054
# Epoch 10/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0062 - val_loss: 0.0050
# Epoch 11/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0057 - val_loss: 0.0046
# Epoch 12/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0053 - val_loss: 0.0043
# Epoch 13/150
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0050 - val_loss: 0.0040
# Epoch 14/150
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0046 - val_loss: 0.0037
# Epoch 15/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0043 - val_loss: 0.0035
# Epoch 16/150
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0040 - val_loss: 0.0033
# Epoch 17/150
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0037 - val_loss: 0.0031
# Epoch 18/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0035 - val_loss: 0.0029
# Epoch 19/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0033 - val_loss: 0.0028
# Epoch 20/150
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0031 - val_loss: 0.0027
# Epoch 21/150
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0029 - val_loss: 0.0026
# Epoch 22/150
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0028 - val_loss: 0.0025
# Epoch 23/150
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0026 - val_loss: 0.0024
# Epoch 24/150
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0025 - val_loss: 0.0023
# Epoch 25/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0024 - val_loss: 0.0022
# Epoch 26/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0022 - val_loss: 0.0021
# Epoch 27/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0022 - val_loss: 0.0021
# Epoch 28/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0021 - val_loss: 0.0020
# Epoch 29/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0020 - val_loss: 0.0020
# Epoch 30/150
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 31/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 32/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0018 - val_loss: 0.0020
# Epoch 33/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0018 - val_loss: 0.0020
# Epoch 34/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0017 - val_loss: 0.0019
# Epoch 35/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0017 - val_loss: 0.0018
# Epoch 36/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0016 - val_loss: 0.0018
# Epoch 37/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0016 - val_loss: 0.0018
# Epoch 38/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0016 - val_loss: 0.0018
# Epoch 39/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0016 - val_loss: 0.0019
# Epoch 40/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0015 - val_loss: 0.0019
# Epoch 41/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0015 - val_loss: 0.0019
# Epoch 42/150
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0015 - val_loss: 0.0018
# Epoch 43/150
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0015 - val_loss: 0.0018
# Epoch 44/150
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0014 - val_loss: 0.0018
# Epoch 45/150
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0014 - val_loss: 0.0018
# Epoch 46/150
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0014 - val_loss: 0.0018
# Epoch 47/150
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0014 - val_loss: 0.0019
# Epoch 48/150
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0014 - val_loss: 0.0018
# Epoch 49/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0014 - val_loss: 0.0018
# Epoch 50/150
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0014 - val_loss: 0.0018
# Epoch 51/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0013 - val_loss: 0.0018
# Epoch 52/150
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0013 - val_loss: 0.0017
# Epoch 53/150
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0013 - val_loss: 0.0018
# Epoch 54/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0013 - val_loss: 0.0018
# Epoch 55/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0013 - val_loss: 0.0018
# Epoch 56/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0013 - val_loss: 0.0018
# Epoch 57/150
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0013 - val_loss: 0.0018
# Epoch 58/150
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0013 - val_loss: 0.0018
# Epoch 59/150
# 4/4 [==============================] - 0s 31ms/step - loss: 0.0012 - val_loss: 0.0018
# Epoch 60/150
# 4/4 [==============================] - 0s 26ms/step - loss: 0.0012 - val_loss: 0.0018
# Epoch 61/150
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0012 - val_loss: 0.0018
# Epoch 62/150
# 4/4 [==============================] - 0s 28ms/step - loss: 0.0012 - val_loss: 0.0018
# Epoch 63/150
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0012 - val_loss: 0.0018
# Epoch 64/150
# 4/4 [==============================] - 0s 34ms/step - loss: 0.0012 - val_loss: 0.0018
# Epoch 65/150
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0012 - val_loss: 0.0018
# Epoch 66/150
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0012 - val_loss: 0.0018
# Epoch 67/150
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0012 - val_loss: 0.0019
# Epoch 68/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0012 - val_loss: 0.0018
# Epoch 69/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0012 - val_loss: 0.0018
# Epoch 70/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0012 - val_loss: 0.0018
# Epoch 71/150
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0012 - val_loss: 0.0019
# Epoch 72/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0011 - val_loss: 0.0019
# Epoch 73/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0011 - val_loss: 0.0019
# Epoch 74/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0011 - val_loss: 0.0019
# Epoch 75/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0011 - val_loss: 0.0019
# Epoch 76/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0011 - val_loss: 0.0019
# Epoch 77/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0011 - val_loss: 0.0019
# Epoch 78/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0011 - val_loss: 0.0019
# Epoch 79/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0011 - val_loss: 0.0019
# Epoch 80/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0011 - val_loss: 0.0019
# Epoch 81/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0011 - val_loss: 0.0019
# Epoch 82/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0011 - val_loss: 0.0019
# Epoch 83/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0011 - val_loss: 0.0019
# Epoch 84/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0011 - val_loss: 0.0019
# Epoch 85/150
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0011 - val_loss: 0.0019
# Epoch 86/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0011 - val_loss: 0.0019
# Epoch 87/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0010 - val_loss: 0.0019
# Epoch 88/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0010 - val_loss: 0.0019
# Epoch 89/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0010 - val_loss: 0.0019
# Epoch 90/150
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0010 - val_loss: 0.0019
# Epoch 91/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0010 - val_loss: 0.0020
# Epoch 92/150
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0010 - val_loss: 0.0020
# Epoch 93/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0010 - val_loss: 0.0020
# Epoch 94/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0010 - val_loss: 0.0020
# Epoch 95/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0010 - val_loss: 0.0020
# Epoch 96/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0010 - val_loss: 0.0020
# Epoch 97/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0010 - val_loss: 0.0020
# Epoch 98/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0010 - val_loss: 0.0019
# Epoch 99/150
# 4/4 [==============================] - 0s 22ms/step - loss: 9.9972e-04 - val_loss: 0.0019
# Epoch 100/150
# 4/4 [==============================] - 0s 26ms/step - loss: 9.9104e-04 - val_loss: 0.0021
# Epoch 101/150
# 4/4 [==============================] - 0s 24ms/step - loss: 9.8301e-04 - val_loss: 0.0020
# Epoch 102/150
# 4/4 [==============================] - 0s 30ms/step - loss: 9.7661e-04 - val_loss: 0.0020
# Epoch 103/150
# 4/4 [==============================] - 0s 18ms/step - loss: 9.7084e-04 - val_loss: 0.0020
# Epoch 104/150
# 4/4 [==============================] - 0s 19ms/step - loss: 9.6309e-04 - val_loss: 0.0020
# Epoch 105/150
# 4/4 [==============================] - 0s 21ms/step - loss: 9.6081e-04 - val_loss: 0.0020
# Epoch 106/150
# 4/4 [==============================] - 0s 25ms/step - loss: 9.5759e-04 - val_loss: 0.0020
# Epoch 107/150
# 4/4 [==============================] - 0s 25ms/step - loss: 9.5588e-04 - val_loss: 0.0020
# Epoch 108/150
# 4/4 [==============================] - 0s 22ms/step - loss: 9.4886e-04 - val_loss: 0.0020
# Epoch 109/150
# 4/4 [==============================] - 0s 22ms/step - loss: 9.4864e-04 - val_loss: 0.0020
# Epoch 110/150
# 4/4 [==============================] - 0s 23ms/step - loss: 9.5057e-04 - val_loss: 0.0021
# Epoch 111/150
# 4/4 [==============================] - 0s 18ms/step - loss: 9.3796e-04 - val_loss: 0.0020
# Epoch 112/150
# 4/4 [==============================] - 0s 23ms/step - loss: 9.3473e-04 - val_loss: 0.0020
# Epoch 113/150
# 4/4 [==============================] - 0s 19ms/step - loss: 9.3022e-04 - val_loss: 0.0021
# Epoch 114/150
# 4/4 [==============================] - 0s 18ms/step - loss: 9.3111e-04 - val_loss: 0.0021
# Epoch 115/150
# 4/4 [==============================] - 0s 17ms/step - loss: 9.2263e-04 - val_loss: 0.0021
# Epoch 116/150
# 4/4 [==============================] - 0s 18ms/step - loss: 9.2280e-04 - val_loss: 0.0021
# Epoch 117/150
# 4/4 [==============================] - 0s 22ms/step - loss: 9.1543e-04 - val_loss: 0.0021
# Epoch 118/150
# 4/4 [==============================] - 0s 24ms/step - loss: 9.1463e-04 - val_loss: 0.0020
# Epoch 119/150
# 4/4 [==============================] - 0s 21ms/step - loss: 9.1186e-04 - val_loss: 0.0021
# Epoch 120/150
# 4/4 [==============================] - 0s 23ms/step - loss: 9.0629e-04 - val_loss: 0.0021
# Epoch 121/150
# 4/4 [==============================] - 0s 21ms/step - loss: 9.0760e-04 - val_loss: 0.0022
# Epoch 122/150
# 4/4 [==============================] - 0s 20ms/step - loss: 9.1048e-04 - val_loss: 0.0022
# Epoch 123/150
# 4/4 [==============================] - 0s 18ms/step - loss: 8.9907e-04 - val_loss: 0.0021
# Epoch 124/150
# 4/4 [==============================] - 0s 19ms/step - loss: 8.9472e-04 - val_loss: 0.0021
# Epoch 125/150
# 4/4 [==============================] - 0s 16ms/step - loss: 8.9090e-04 - val_loss: 0.0021
# Epoch 126/150
# 4/4 [==============================] - 0s 16ms/step - loss: 8.8480e-04 - val_loss: 0.0021
# Epoch 127/150
# 4/4 [==============================] - 0s 17ms/step - loss: 8.8109e-04 - val_loss: 0.0021
# Epoch 128/150
# 4/4 [==============================] - 0s 20ms/step - loss: 8.8304e-04 - val_loss: 0.0021
# Epoch 129/150
# 4/4 [==============================] - 0s 16ms/step - loss: 8.7056e-04 - val_loss: 0.0021
# Epoch 130/150
# 4/4 [==============================] - 0s 15ms/step - loss: 8.6480e-04 - val_loss: 0.0022
# Epoch 131/150
# 4/4 [==============================] - 0s 30ms/step - loss: 8.6550e-04 - val_loss: 0.0022
# Epoch 132/150
# 4/4 [==============================] - 0s 28ms/step - loss: 8.6564e-04 - val_loss: 0.0022
# Epoch 133/150
# 4/4 [==============================] - 0s 23ms/step - loss: 8.6373e-04 - val_loss: 0.0021
# Epoch 134/150
# 4/4 [==============================] - 0s 16ms/step - loss: 8.5529e-04 - val_loss: 0.0021
# Epoch 135/150
# 4/4 [==============================] - 0s 18ms/step - loss: 8.4837e-04 - val_loss: 0.0022
# Epoch 136/150
# 4/4 [==============================] - 0s 29ms/step - loss: 8.4289e-04 - val_loss: 0.0022
# Epoch 137/150
# 4/4 [==============================] - 0s 20ms/step - loss: 8.4836e-04 - val_loss: 0.0022
# Epoch 138/150
# 4/4 [==============================] - 0s 21ms/step - loss: 8.5162e-04 - val_loss: 0.0021
# Epoch 139/150
# 4/4 [==============================] - 0s 22ms/step - loss: 8.3511e-04 - val_loss: 0.0022
# Epoch 140/150
# 4/4 [==============================] - 0s 18ms/step - loss: 8.3057e-04 - val_loss: 0.0022
# Epoch 141/150
# 4/4 [==============================] - 0s 19ms/step - loss: 8.3374e-04 - val_loss: 0.0022
# Epoch 142/150
# 4/4 [==============================] - 0s 12ms/step - loss: 8.2316e-04 - val_loss: 0.0022
# Epoch 143/150
# 4/4 [==============================] - 0s 16ms/step - loss: 8.1777e-04 - val_loss: 0.0021
# Epoch 144/150
# 4/4 [==============================] - 0s 20ms/step - loss: 8.1893e-04 - val_loss: 0.0021
# Epoch 145/150
# 4/4 [==============================] - 0s 17ms/step - loss: 8.1925e-04 - val_loss: 0.0022
# Epoch 146/150
# 4/4 [==============================] - 0s 17ms/step - loss: 8.1441e-04 - val_loss: 0.0022
# Epoch 147/150
# 4/4 [==============================] - 0s 14ms/step - loss: 8.0423e-04 - val_loss: 0.0021
# Epoch 148/150
# 4/4 [==============================] - 0s 18ms/step - loss: 8.0216e-04 - val_loss: 0.0021
# Epoch 149/150
# 4/4 [==============================] - 0s 19ms/step - loss: 8.0500e-04 - val_loss: 0.0021
# Epoch 150/150
# 4/4 [==============================] - 0s 17ms/step - loss: 7.9989e-04 - val_loss: 0.0021

# %% [markdown]
# **From the training summary, you can see test losses reaches 0.0018 around 40 epochs before wavering between 0.0019 ad 0.0021 until the end. You may want to reduce number of epochs.**

# %%
plt.plot(r.history['loss'], label='train loss')
plt.plot(r.history['val_loss'], label='test loss')
plt.title("Basic ANN Performance")
plt.legend();

# %% [markdown]
# **As you can see, both training and test losses decrease steadily and converge around 25 epochs.**

# %%
# For Boolean indexing, first T + 1 values are not predictable

train_idx[:T+1] = False

# %%
# Predict with model (remember that this is differenced data)

P_train = model.predict(X_train).flatten()

P_test = model.predict(X_test).flatten()
# Out:
# 4/4 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 32ms/step

# %%
# Store differenced predictions in original data

df.loc[train_idx, 'Diff ANN Train Prediction'] = P_train
df.loc[test_idx, 'Diff ANN Test Prediction'] = P_test

# %%
# Plot differenced results against diffed data

cols = ['DiffLogPassengers', 'Diff ANN Train Prediction', 'Diff ANN Test Prediction']

df[cols].plot(figsize=(15, 5))
plt.title("ANN Data Predictions for differenced data");

# %% [markdown]
# **This looks pretty good, but remember this is just the one-step prediction for differenced data.**
#
# ### Compute 'un-differenced' predictions
#
# **Shift the log-transformed data up by one and store in a separate variable. Use that variable to index the training and test sets at the shifted index positions to add the predictions at the correct date.**

# %%
df['ShiftLogPassengers'] = df['LogPassengers'].shift(1)

prev = df['ShiftLogPassengers']

# %%
# Obtain last-known training value

last_train = train.iloc[-1]['LogPassengers']

# %% [markdown]
# ### One-step forecast
#
# **Add the predictions for the differenced data at the shifted index locations so that the date values match up.**

# %%
df.loc[train_idx, 'onestep_train'] = prev[train_idx] + P_train

df.loc[test_idx, 'onestep_test'] = prev[test_idx] + P_test

# %%
df[['LogPassengers', 'onestep_train', 'onestep_test']].plot(figsize=(15, 5))
plt.title("One-step forecast");

# %% [markdown]
# ### Incremental Multi-step forecast

# %%
multistep_predictions = []

# Obtain first test input
last_x = X_test[0]

while len(multistep_predictions) < N_test:
    p = model.predict(last_x.reshape(1, -1))[0]
    
    # Update the predictions list
    multistep_predictions.append(p)
    
    # Make the new input
    last_x = np.roll(last_x, -1)
    last_x[-1] = p

# %%
# Save multi-step forecast to dataframe

df.loc[test_idx, 'multistep'] = last_train + np.cumsum(multistep_predictions)

# %%
df[['LogPassengers', 'multistep', '1step_test']].plot(figsize=(15, 5))
plt.title("One-step and incremental Multi-step forecasts");

# %% [markdown]
# ### Multi-output Multi-step forecast
#
# **You need to re-create the 'supervised' dataset, so that the target variable *Y* contains the multiple prediction outputs for T past lags for each sample.**

# %%
Tx = T
Ty = N_test
X = []
Y = []

for t in range(len(series) - Tx - Ty + 1):
    x = series[t:t+Tx]
    X.append(x)
    y = series[t+Tx:t+Tx+Ty]
    Y.append(y)

# Convert to NumPy array easier to index
X = np.array(X).reshape(-1, Tx)
Y = np.array(Y).reshape(-1, Ty)

N = len(X)

print("X.shape", X.shape, "Y.shape", Y.shape)

# %%
# Use different naming for training and test sets

Xtrain, Ytrain = X[:-1], Y[:-1]

Xtest, Ytest = X[-1:], Y[-1:]

# %% [markdown]
# ### Rebuild basic ANN
#
# **You need to re-build the ANN because the structure specifications have changed, as well as new training and test sets from the new supervised dataset.**

# %%
i = Input(shape=(Tx,))

x = Dense(32, activation='relu')(i)

x = Dense(Ty)(x)

model = Model(i, x)

# %%
model.compile(loss='mse', optimizer='adam')

# %%
r = model.fit(Xtrain, 
              Ytrain, 
              epochs=150, 
              validation_data=(Xtest, Ytest))

# %%
plt.plot(r.history['loss'], label='train loss')
plt.plot(r.history['val_loss'], label='test loss')
plt.title("Basic ANN performance")
plt.legend();

# %%
# Predict with model

Ptrain = model.predict(Xtrain)

Ptest = model.predict(Xtest)

# %%
Ptrain.shape, Ptest.shape

# %%
Ptrain = Ptrain[:, 0]

Ptest = Ptest[0]

# %%
# Save multi-output forecast to dataframe

df.loc[test_idx, 'multioutput'] = last_train + np.cumsum(Ptest)

# %%
# Plot all forecasts

cols = ['LogPassengers', 'multistep', '1step_test', 'multioutput']

df[cols].plot(figsize=(15, 5))
plt.title("One-step, incremental Multi-Step and Multi-Output forecasts");

# %%
# Compute MAPE

test_log_pass = df.iloc[-N_test:]['LogPassengers']

mape1 = mean_absolute_percentage_error(test_log_pass, df.loc[test_idx, 'multistep'])
print("multi-step MAPE:", mape1)

mape2 = mean_absolute_percentage_error(test_log_pass, df.loc[test_idx, 'multioutput'])
print("multi-output MAPE:", mape2)

# %%
# Exercise:
# Do you think differencing is unnecessary? Try it!
# Do you think logging is unnecessary? Try it!
# Do you think including more past lags would be useful?
# Have you considered walk-forward validation to optimize hyperparameters?
